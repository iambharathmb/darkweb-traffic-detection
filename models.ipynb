# %% [markdown]
# # DNN Model

# %%
import pandas as pd
import keras as keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Preprocess the data (e.g., normalization, scaling)
data = pd.read_csv("model_samples.csv")

# Assuming you have your input features in X and corresponding target values in y
x = data.drop(columns=["Label"])
y = data["Label"]

# Perform any necessary preprocessing steps here, such as normalization or scaling
x = pd.get_dummies(x)
y = pd.get_dummies(y)

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Build the DNN model
model = Sequential([
    Dense(64, activation='relu'),  # Input layer
    Dense(32, activation='relu'),  # Hidden layer
    Dense(1, activation="linear"),  # Output layer
])

# Compile the model
model.compile(optimizer='adam',
              loss='mae',
              metrics=['accuracy'])


# Train the model
history = model.fit(x_train, y_train, epochs=20, verbose=0)

# Plot the test loss and test accuracy
plt.plot(history.history['loss'])
plt.plot(history.history['accuracy'])
plt.title(' loss and accuracy')
plt.xlabel('Epoch')
plt.ylabel('Loss/Accuracy')
plt.legend(['Loss', 'Accuracy'])
plt.show()

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test loss: {test_loss}')
print(f'Test accuracy: {test_acc}')

# Make predictions
predictions = model.predict(x_test[:1])
print('Predictions:', predictions)
# Out:
# 885/885 [==============================] - 1s 1ms/step - loss: 0.5000 - accuracy: 0.5000
# Test loss: 0.5
# Test accuracy: 0.5
# 1/1 [==============================] - 0s 81ms/step
# Predictions: [[0.5238551]]

# %%
import pandas as pd
import keras as keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Preprocess the data (e.g., normalization, scaling)
data = pd.read_csv("model_samples.csv")

# Assuming you have your input features in X and corresponding target values in y
x = data.drop(columns=["Label"])
y = data["Label"]

# Perform any necessary preprocessing steps here, such as normalization or scaling
x = pd.get_dummies(x)
y = pd.get_dummies(y)

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Build the DNN model
model = Sequential([
    Dense(64, activation='relu'),  # Input layer
    Dense(32, activation='relu'),  # Hidden layer
    Dense(1, activation="softmax"),  # Output layer
])

# Compile the model
model.compile(optimizer='adam',
              loss='mse',
              metrics=['accuracy'])


# Train the model
history = model.fit(x_train, y_train, epochs=20, verbose=0)

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test loss: {test_loss}')
print(f'Test accuracy: {test_acc}')

# Plot the test loss and test accuracy
plt.plot(history.history['loss'])
plt.plot(history.history['accuracy'])
plt.title('loss and accuracy')
plt.xlabel('Epoch')
plt.ylabel('Loss/Accuracy')
plt.legend(['Loss', 'Accuracy'])
plt.show()

# Make predictions
predictions = model.predict(x_test[:1])
print('Predictions:', predictions)
# Out:
# 885/885 [==============================] - 1s 1ms/step - loss: 0.5000 - accuracy: 0.5000
# Test loss: 0.5
# Test accuracy: 0.5
# 1/1 [==============================] - 0s 63ms/step
# Predictions: [[1.]]

# %%
import pandas as pd
import keras as keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Preprocess the data (e.g., normalization, scaling)
data = pd.read_csv("model_samples.csv")

# Assuming you have your input features in X and corresponding target values in y
x = data.drop(columns=["Label"])
y = data["Label"]

# Perform any necessary preprocessing steps here, such as normalization or scaling
x = pd.get_dummies(x)
y = pd.get_dummies(y)

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Build the DNN model
model = Sequential([
    Dense(64, activation='relu'),  # Input layer
    Dense(32, activation='relu'),  # Hidden layer
    Dense(1, activation="softmax"),  # Output layer
])

# Compile the model
model.compile(optimizer='SGD',
              loss='mse',
              metrics=['accuracy'])


# Train the model
history = model.fit(x_train, y_train, epochs=20, verbose=0)

# Plot the test loss and test accuracy
plt.plot(history.history['loss'])
plt.plot(history.history['accuracy'])
plt.title('loss and accuracy')
plt.xlabel('Epoch')
plt.ylabel('Loss/Accuracy')
plt.legend(['Loss', 'Accuracy'])
plt.show()

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test loss: {test_loss}')
print(f'Test accuracy: {test_acc}')

# Make predictions
predictions = model.predict(x_test[:1])
print('Predictions:', predictions)
# Out:
# 885/885 [==============================] - 1s 1ms/step - loss: 0.5000 - accuracy: 0.5000
# Test loss: 0.5
# Test accuracy: 0.5
# 1/1 [==============================] - 0s 72ms/step
# Predictions: [[1.]]

# %%
import pandas as pd
import keras as keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Preprocess the data (e.g., normalization, scaling)
data = pd.read_csv("model_samples.csv")

# Assuming you have your input features in X and corresponding target values in y
x = data.drop(columns=["Label"])
y = data["Label"]

# Perform any necessary preprocessing steps here, such as normalization or scaling
x = pd.get_dummies(x)
y = pd.get_dummies(y)

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Build the DNN model
model = Sequential([
    Dense(64, activation='relu'),  # Input layer
    Dense(32, activation='relu'),  # Hidden layer
    Dense(1, activation="softmax"),  # Output layer
])

# Compile the model
model.compile(optimizer='adam',
              loss='mae',
              metrics=['accuracy'])


# Train the model
history = model.fit(x_train, y_train, epochs=20, verbose=0)

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test loss: {test_loss}')
print(f'Test accuracy: {test_acc}')

# Plot the test loss and test accuracy
plt.plot(history.history['loss'])
plt.plot(history.history['accuracy'])
plt.title('loss and accuracy')
plt.xlabel('Epoch')
plt.ylabel('Loss/Accuracy')
plt.legend(['Loss', 'Accuracy'])
plt.show()

# Make predictions
predictions = model.predict(x_test[:1])
print('Predictions:', predictions)
# Out:
# 885/885 [==============================] - 1s 869us/step - loss: 0.5000 - accuracy: 0.5000
# Test loss: 0.5
# Test accuracy: 0.5
# 1/1 [==============================] - 0s 63ms/step
# Predictions: [[1.]]

# %%
import pandas as pd
import keras as keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Preprocess the data (e.g., normalization, scaling)
data = pd.read_csv("model_samples.csv")

# Assuming you have your input features in X and corresponding target values in y
x = data.drop(columns=["Label"])
y = data["Label"]

# Perform any necessary preprocessing steps here, such as normalization or scaling
x = pd.get_dummies(x)
y = pd.get_dummies(y)

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Build the DNN model
model = Sequential([
    Dense(64, activation='relu'),  # Input layer
    Dense(32, activation='relu'),  # Hidden layer
    Dense(1, activation="sigmoid"),  # Output layer
])

# Compile the model
model.compile(optimizer='adam',
              loss='mse',
              metrics=['accuracy'])


# Train the model
history = model.fit(x_train, y_train, epochs=20, verbose=0)

# Plot the test loss and test accuracy
plt.plot(history.history['loss'])
plt.plot(history.history['accuracy'])
plt.title('loss and accuracy')
plt.xlabel('Epoch')
plt.ylabel('Loss/Accuracy')
plt.legend(['Loss', 'Accuracy'])
plt.show()

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test loss: {test_loss}')
print(f'Test accuracy: {test_acc}')

# Make predictions
predictions = model.predict(x_test[:1])
print('Predictions:', predictions)
# Out:
# 885/885 [==============================] - 1s 1ms/step - loss: 0.4998 - accuracy: 0.5000
# Test loss: 0.4998144805431366
# Test accuracy: 0.5
# 1/1 [==============================] - 0s 81ms/step
# Predictions: [[0.5]]

# %%
import pandas as pd
import keras as keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Preprocess the data (e.g., normalization, scaling)
data = pd.read_csv("model_samples.csv")

# Assuming you have your input features in X and corresponding target values in y
x = data.drop(columns=["Label"])
y = data["Label"]

# Perform any necessary preprocessing steps here, such as normalization or scaling
x = pd.get_dummies(x)
y = pd.get_dummies(y)

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Build the DNN model
model = Sequential([
    Dense(64, activation='relu'),  # Input layer
    Dense(32, activation='relu'),  # Hidden layer
    Dense(1, activation="sigmoid"),  # Output layer
])

# Compile the model
model.compile(optimizer='SGD',
              loss='mse',
              metrics=['accuracy'])


# Train the model
history = model.fit(x_train, y_train, epochs=20, verbose=0)

# Plot the test loss and test accuracy
plt.plot(history.history['loss'])
plt.plot(history.history['accuracy'])
plt.title('loss and accuracy')
plt.xlabel('Epoch')
plt.ylabel('Loss/Accuracy')
plt.legend(['Loss', 'Accuracy'])
plt.show()

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test loss: {test_loss}')
print(f'Test accuracy: {test_acc}')

# Make predictions
predictions = model.predict(x_test[:1])
print('Predictions:', predictions)
# Out:
# 885/885 [==============================] - 1s 1ms/step - loss: 0.4998 - accuracy: 0.5000
# Test loss: 0.4998176097869873
# Test accuracy: 0.5
# 1/1 [==============================] - 0s 66ms/step
# Predictions: [[0.6530845]]

# %%
import pandas as pd
import keras as keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Preprocess the data (e.g., normalization, scaling)
data = pd.read_csv("model_samples.csv")

# Assuming you have your input features in X and corresponding target values in y
x = data.drop(columns=["Label"])
y = data["Label"]

# Perform any necessary preprocessing steps here, such as normalization or scaling
x = pd.get_dummies(x)
y = pd.get_dummies(y)

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Build the DNN model
model = Sequential([
    Dense(64, activation='relu'),  # Input layer
    Dense(32, activation='relu'),  # Hidden layer
    Dense(1, activation="sigmoid"),  # Output layer
])

# Compile the model
model.compile(optimizer='adam',
              loss='mae',
              metrics=['accuracy'])


# Train the model
history = model.fit(x_train, y_train, epochs=20, verbose=0)

# Plot the test loss and test accuracy
plt.plot(history.history['loss'])
plt.plot(history.history['accuracy'])
plt.title('loss and accuracy')
plt.xlabel('Epoch')
plt.ylabel('Loss/Accuracy')
plt.legend(['Loss', 'Accuracy'])
plt.show()

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test loss: {test_loss}')
print(f'Test accuracy: {test_acc}')

# Make predictions
predictions = model.predict(x_test[:1])
print('Predictions:', predictions)
# Out:
# 885/885 [==============================] - 1s 1ms/step - loss: 0.5000 - accuracy: 0.5000
# Test loss: 0.5
# Test accuracy: 0.5
# 1/1 [==============================] - 0s 83ms/step
# Predictions: [[0.31101662]]

# %%
import pandas as pd
import keras as keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Preprocess the data (e.g., normalization, scaling)
data = pd.read_csv("model_samples.csv")

# Assuming you have your input features in X and corresponding target values in y
x = data.drop(columns=["Label"])
y = data["Label"]

# Perform any necessary preprocessing steps here, such as normalization or scaling
x = pd.get_dummies(x)
y = pd.get_dummies(y)

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Build the DNN model
model = Sequential([
    Dense(64, activation='relu'),  # Input layer
    Dense(32, activation='relu'),  # Hidden layer
    Dense(1, activation="linear"),  # Output layer
])

# Compile the model
model.compile(optimizer='rmsprop',
              loss='mae',
              metrics=['accuracy'])


# Train the model
history = model.fit(x_train, y_train, epochs=20, verbose=0)

# Plot the test loss and test accuracy
plt.plot(history.history['loss'])
plt.plot(history.history['accuracy'])
plt.title('loss and accuracy')
plt.xlabel('Epoch')
plt.ylabel('Loss/Accuracy')
plt.legend(['Loss', 'Accuracy'])
plt.show()

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test loss: {test_loss}')
print(f'Test accuracy: {test_acc}')

# Make predictions
predictions = model.predict(x_test[:1])
print('Predictions:', predictions)
# Out:
# 885/885 [==============================] - 1s 1ms/step - loss: 0.5000 - accuracy: 0.5000
# Test loss: 0.5
# Test accuracy: 0.5
# 1/1 [==============================] - 0s 80ms/step
# Predictions: [[0.26428777]]
